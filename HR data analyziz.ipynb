# %%
import pandas as pd
df = pd.read_csv("HR_analytics.csv")
df
# Out:
#        EmpID  Age AgeGroup Attrition     BusinessTravel  DailyRate  \
# 0      RM297   18    18-25       Yes      Travel_Rarely        230
# 1      RM302   18    18-25        No      Travel_Rarely        812
# 2      RM458   18    18-25       Yes  Travel_Frequently       1306
# 3      RM728   18    18-25        No         Non-Travel        287
# 4      RM829   18    18-25       Yes         Non-Travel        247
# ...      ...  ...      ...       ...                ...        ...
# 1475   RM412   60      55+        No      Travel_Rarely        422
# 1476   RM428   60      55+        No  Travel_Frequently       1499
# 1477   RM537   60      55+        No      Travel_Rarely       1179
# 1478   RM880   60      55+        No      Travel_Rarely        696
# 1479  RM1210   60      55+        No      Travel_Rarely        370
#
#                   Department  DistanceFromHome  Education EducationField  ...  \
# 0     Research & Development                 3          3  Life Sciences  ...
# ...

# %%
df.drop_duplicates(subset=['EmpID'])
df
# remove all rows that contain null values
df = df.dropna(how="any")
df
# Out:
#        EmpID  Age AgeGroup Attrition     BusinessTravel  DailyRate  \
# 0      RM297   18    18-25       Yes      Travel_Rarely        230
# 1      RM302   18    18-25        No      Travel_Rarely        812
# 2      RM458   18    18-25       Yes  Travel_Frequently       1306
# 3      RM728   18    18-25        No         Non-Travel        287
# 4      RM829   18    18-25       Yes         Non-Travel        247
# ...      ...  ...      ...       ...                ...        ...
# 1475   RM412   60      55+        No      Travel_Rarely        422
# 1476   RM428   60      55+        No  Travel_Frequently       1499
# 1477   RM537   60      55+        No      Travel_Rarely       1179
# 1478   RM880   60      55+        No      Travel_Rarely        696
# 1479  RM1210   60      55+        No      Travel_Rarely        370
#
#                   Department  DistanceFromHome  Education EducationField  ...  \
# 0     Research & Development                 3          3  Life Sciences  ...
# ...

# %%
print(df['EmployeeCount'].value_counts())
print(df['Over18'].value_counts())
age_groups = df['AgeGroup'].value_counts()
age_groups
# Out:
# 1    1423
# Name: EmployeeCount, dtype: int64
# Y    1423
# Name: Over18, dtype: int64
# 26-35    590
# 36-45    449
# 46-55    223
# 18-25    117
# 55+       44
# Name: AgeGroup, dtype: int64

# %%
df = df.drop(columns=["AgeGroup","EmployeeCount","Over18"])
df
# Out:
#        EmpID  Age Attrition     BusinessTravel  DailyRate  \
# 0      RM297   18       Yes      Travel_Rarely        230
# 1      RM302   18        No      Travel_Rarely        812
# 2      RM458   18       Yes  Travel_Frequently       1306
# 3      RM728   18        No         Non-Travel        287
# 4      RM829   18       Yes         Non-Travel        247
# ...      ...  ...       ...                ...        ...
# 1475   RM412   60        No      Travel_Rarely        422
# 1476   RM428   60        No  Travel_Frequently       1499
# 1477   RM537   60        No      Travel_Rarely       1179
# 1478   RM880   60        No      Travel_Rarely        696
# 1479  RM1210   60        No      Travel_Rarely        370
#
#                   Department  DistanceFromHome  Education EducationField  \
# 0     Research & Development                 3          3  Life Sciences
# 1                      Sales                10          3        Medical
# ...

# %%
for column_name in ['Attrition','OverTime']:
    df[column_name] = df[column_name].replace({'Yes': 1, 'No': 0})
df
# Out:
#        EmpID  Age  Attrition     BusinessTravel  DailyRate  \
# 0      RM297   18          1      Travel_Rarely        230
# 1      RM302   18          0      Travel_Rarely        812
# 2      RM458   18          1  Travel_Frequently       1306
# 3      RM728   18          0         Non-Travel        287
# 4      RM829   18          1         Non-Travel        247
# ...      ...  ...        ...                ...        ...
# 1475   RM412   60          0      Travel_Rarely        422
# 1476   RM428   60          0  Travel_Frequently       1499
# 1477   RM537   60          0      Travel_Rarely       1179
# 1478   RM880   60          0      Travel_Rarely        696
# 1479  RM1210   60          0      Travel_Rarely        370
#
#                   Department  DistanceFromHome  Education EducationField  \
# 0     Research & Development                 3          3  Life Sciences
# 1                      Sales                10          3        Medical
# ...

# %%
df['BusinessTravel'].value_counts()
# Out:
# Travel_Rarely        998
# Travel_Frequently    270
# Non-Travel           148
# TravelRarely           7
# Name: BusinessTravel, dtype: int64

# %%
df['BusinessTravel'] = df['BusinessTravel'].replace({'Travel_Frequently': 1,'Travel_Rarely':0.5,'TravelRarely':0.5, 'Non-Travel': 0})
df
# Out:
#        EmpID  Age  Attrition  BusinessTravel  DailyRate  \
# 0      RM297   18          1             0.5        230
# 1      RM302   18          0             0.5        812
# 2      RM458   18          1             1.0       1306
# 3      RM728   18          0             0.0        287
# 4      RM829   18          1             0.0        247
# ...      ...  ...        ...             ...        ...
# 1475   RM412   60          0             0.5        422
# 1476   RM428   60          0             1.0       1499
# 1477   RM537   60          0             0.5       1179
# 1478   RM880   60          0             0.5        696
# 1479  RM1210   60          0             0.5        370
#
#                   Department  DistanceFromHome  Education EducationField  \
# 0     Research & Development                 3          3  Life Sciences
# 1                      Sales                10          3        Medical
# ...

# %%
print(df['Department'].value_counts())
print(df['EducationField'].value_counts())
# Out:
# Research & Development    924
# Sales                     437
# Human Resources            62
# Name: Department, dtype: int64
# Life Sciences       586
# Medical             446
# Marketing           155
# Technical Degree    129
# Other                81
# Human Resources      26
# Name: EducationField, dtype: int64

# %%
print(df['SalarySlab'].value_counts())
# Out:
# Upto 5k    721
# 5k-10k     428
# 10k-15k    144
# 15k+       130
# Name: SalarySlab, dtype: int64

# %%
print(df['Gender'].value_counts(),"\n")
print(df['MaritalStatus'].value_counts(),"\n")
print(df['JobRole'].value_counts(),"\n")
print(df['StandardHours'].value_counts())
# Out:
# 1    854
# 0    569
# Name: Gender, dtype: int64
#
# 0    768
# 1    655
# Name: MaritalStatus, dtype: int64
#
# Sales Executive              318
# Research Scientist           276
# Laboratory Technician        250
# Manufacturing Director       141
# Healthcare Representative    127
# Manager                      100
# Sales Representative          83
# Research Director             77
# Human Resources               51
# Name: JobRole, dtype: int64
#
# 80    1423
# Name: StandardHours, dtype: int64

# %%
standard_hours = 80
df = df.drop(columns="StandardHours")

# %%
df['MaritalStatus'] = df['MaritalStatus'].replace({'Married': 1, 'Single': 0,'Divorced':0})
df['Gender'] = df['Gender'].replace({'Male': 1, 'Female': 0})

# %%
df.corr()
# Out:
# C:\Users\Fc\AppData\Local\Temp\ipykernel_15952\1134722465.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.corr()
#                                Age  Attrition  BusinessTravel  DailyRate  \
# Age                       1.000000  -0.153621       -0.014789   0.012164
# Attrition                -0.153621   1.000000        0.125856  -0.055527
# BusinessTravel           -0.014789   0.125856        1.000000  -0.009741
# DailyRate                 0.012164  -0.055527       -0.009741   1.000000
# DistanceFromHome          0.010473   0.078189       -0.011942  -0.008461
# Education                 0.206874  -0.025496       -0.000877  -0.007906
# EmployeeNumber           -0.012972  -0.015825       -0.015751  -0.059837
# EnvironmentSatisfaction   0.006907  -0.098358       -0.001988   0.019502
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt
plt.figure(figsize=(18, 10))
# Create the heatmap
sns.heatmap(round(df.select_dtypes(include='number').corr(),2), cbar=True, annot=True)
# Out:
# <Axes: >

# %%
df.columns
# Out:
# Index(['EmpID', 'Age', 'Attrition', 'BusinessTravel', 'DailyRate',
#        'Department', 'DistanceFromHome', 'Education', 'EducationField',
#        'EmployeeNumber', 'EnvironmentSatisfaction', 'Gender', 'HourlyRate',
#        'JobInvolvement', 'JobLevel', 'JobRole', 'JobSatisfaction',
#        'MaritalStatus', 'MonthlyIncome', 'SalarySlab', 'MonthlyRate',
#        'NumCompaniesWorked', 'OverTime', 'PercentSalaryHike',
#        'PerformanceRating', 'RelationshipSatisfaction', 'StockOptionLevel',
#        'TotalWorkingYears', 'TrainingTimesLastYear', 'WorkLifeBalance',
#        'YearsAtCompany', 'YearsInCurrentRole', 'YearsSinceLastPromotion',
#        'YearsWithCurrManager'],
#       dtype='object')

# %%
plt.figure(figsize=(10, 8))
sns.heatmap(round(df[['Age','Attrition','JobLevel','MonthlyIncome','TotalWorkingYears','PercentSalaryHike',
       'PerformanceRating','YearsAtCompany', 'YearsInCurrentRole', 'YearsSinceLastPromotion',
       'YearsWithCurrManager','OverTime','StockOptionLevel','MaritalStatus','NumCompaniesWorked','Education']].corr(),2),cbar=True,annot=True)
plt.show()

# %%
sns.heatmap(round(df[['Age','JobLevel','MonthlyIncome','TotalWorkingYears','YearsAtCompany', 'YearsInCurrentRole', 'YearsSinceLastPromotion',
       'YearsWithCurrManager','PercentSalaryHike','PerformanceRating',]].corr(),2),cbar=True,annot=True)
# Out:
# <Axes: >

# %%
df["PerformanceRating"].value_counts()
# Out:
# 3    1208
# 4     215
# Name: PerformanceRating, dtype: int64
